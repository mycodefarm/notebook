# %%
# 把学生的平均分计算出来

# %%
import jutil
import pandas as pd
import numpy as np

# %% [markdown]
# ## 学院分析

# %%
def load_college_students_df(college_code):
    sql = "select *,CONVERT(VARCHAR,birthday,112) as birth from view_stu_course_mark where college_code='%s' and grade='2014'" % college_code
    return jutil.load_pd_df(sql)

# %%
# 信息学院
df = load_college_students_df('04')
df.head()
# Out:
#       birth      birthday city  class_code  class_name college_code  \
# 0  19960615  834768000000   北京  0403201403  通信2014-03班           04
# 1  19960615  834768000000   北京  0403201403  通信2014-03班           04
# 2  19960615  834768000000   北京  0403201403  通信2014-03班           04
# 3  19960615  834768000000   北京  0403201403  通信2014-03班           04
# 4  19960615  834768000000   北京  0403201403  通信2014-03班           04
#
#   college_name course_code course_name course_type    ...     province sex  \
# 0    信息科学与技术学院     0471006    计算机组成原理C           限    ...           北京   男
# 1    信息科学与技术学院     0471006    计算机组成原理C           限    ...           北京   男
# 2    信息科学与技术学院     1271031   概率论与数理统计B           必    ...           北京   男
# 3    信息科学与技术学院     3006655      电路分析BⅡ           必    ...           北京   男
# 4    信息科学与技术学院     3133000      现代通信原理           必    ...           北京   男
#
#   speciality_code speciality_name student_id teach_class_id  teacher term_id  \
# 0            0403            通信工程   20122169              2      唐慧佳      71
# 1            0403            通信工程   20122169              2      唐慧佳      73
# 2            0403            通信工程   20122169              5      李裕奇      78
# 3            0403            通信工程   20122169              2       郭爱      79
# 4            0403            通信工程   20122169              1       郝莉      73
#
#          term_name term_order
# 0    2014-2015第1学期          1
# 1  2014-2015第1学期补考          1
# 2  2015-2016第2学期补考          3
# 3    2016-2017第1学期          3
# 4  2014-2015第1学期补考          1
#
# [5 rows x 27 columns]

# %%
# 要根据学生id聚类然后计算其平均分
def get_avg_stu_marks_df(df):
    groupd  = df.groupby(['student_id','college_code','college_name','sex','name','birth','class_code','class_name','nation_name',
        'party','province','city','speciality_code','speciality_name','grade','constellation'],as_index=False) # 保留列
    groupd = groupd.agg({'pmark':np.average})
    return groupd

# %%
marks = get_avg_stu_marks_df(df)
marks.head()
# Out:
#   student_id college_code college_name sex name     birth  class_code  \
# 0   20122169           04    信息科学与技术学院   男  王钧毅  19960615  0403201403
# 1   20122639           04    信息科学与技术学院   男  杨永虎  19920702  0408201402
# 2   20130068           04    信息科学与技术学院   男  任添笑  19950615  0402201401
# 3   20131649           04    信息科学与技术学院   男   王鑫  19940202  0406201401
# 4   20131664           04    信息科学与技术学院   男  盛守彬  19940208  0406201402
#
#     class_name nation_name        party province city speciality_code  \
# 0   通信2014-03班          汉族  中国共产主义青年团团员       北京   北京            0403
# 1   软件2014-02班          汉族    中国共产党预备党员       山东  聊城市            0408
# 2  计算机2014-01班          汉族  中国共产主义青年团团员       陕西  西安市            0402
# 3   自动2014-01班          汉族  中国共产主义青年团团员       重庆  重庆市            0406
# 4   自动2014-02班          汉族  中国共产主义青年团团员       辽宁  本溪市            0406
#
#   speciality_name grade constellation      pmark
# 0            通信工程  2014           双子座  53.827358
# 1            软件工程  2014           巨蟹座  84.775641
# 2        计算机科学与技术  2014           双子座  81.977778
# 3             自动化  2014           水瓶座  61.821591
# 4             自动化  2014           水瓶座  55.774000

# %%
sex_cnt = marks['sex'].value_counts().to_dict()
type(int(sex_cnt['男']))
# Out:
# int

# %%
# 计算学院男女的平均成绩
g = marks.groupby('sex',as_index=False).agg({'pmark':np.average})
dg = dict(g)
type(dg['pmark'][0].item())
# Out:
# float

# %%
type(marks['pmark'].mean().item())
# Out:
# float

# %%
# 计算学院学霸和学渣人数
g = marks[marks['pmark']>90].groupby('sex',as_index=False).agg({'pmark':'count'}).to_dict()
# dict(g)
len(g['sex'])
# Out:
# 2

# %%
g = marks[marks['pmark']<65].groupby('sex',as_index=False).agg({'pmark':'count'}).to_dict()

# %%
# 计算学院挂科人数
g = df[df['pmark']<60].drop_duplicates(subset=['student_id']).groupby('sex',as_index=False).agg({'pmark':'count'}).to_dict()
g
# Out:
# {'pmark': {0: 74, 1: 342}, 'sex': {0: '女', 1: '男'}}

# %% [markdown]
# ## 特别条件成绩分析

# %% [markdown]
# ## 按星座

# %%
def get_constellation(row):
    birth = str(row['birth'])[4:]
    if (birth>='1222' and birth<='1231') or (birth>='0101' and birth<='0119') :
        return '魔羯座'
    elif birth>='0120' and birth<='0218':
        return '水瓶座'
    elif birth>='0217' and birth<='0320':
        return '双鱼座'
    elif birth>='0319' and birth<='0420':
        return '白羊座'
    elif birth>='0419' and birth<='0520':
        return '金牛座'
    elif birth>='0519' and birth<='0621':
        return '双子座'
    elif birth>='0620' and birth<='0722':
        return '巨蟹座'
    elif birth>='0721' and birth<='0822':
        return '狮子座'
    elif birth>='0821' and birth<='0922':
        return '处女座'
    elif birth>='0921' and birth<='1022':
        return '天秤座'
    elif birth>='1023' and birth<='1121':
        return '天蝎座'
    elif birth>='1122' and birth<='1221':
        return '射手座'
    else:
        return '未知星座'

# %%
# 按星座
df['constellation'] = df.apply(get_constellation,axis=1)
df.head()
# Out:
#       birth      birthday city  class_code  class_name college_code  \
# 0  19960615  834768000000   北京  0403201403  通信2014-03班           04
# 1  19960615  834768000000   北京  0403201403  通信2014-03班           04
# 2  19960615  834768000000   北京  0403201403  通信2014-03班           04
# 3  19960615  834768000000   北京  0403201403  通信2014-03班           04
# 4  19960615  834768000000   北京  0403201403  通信2014-03班           04
#
#   college_name course_code course_name course_type      ...      sex  \
# 0    信息科学与技术学院     0471006    计算机组成原理C           限      ...        男
# 1    信息科学与技术学院     0471006    计算机组成原理C           限      ...        男
# 2    信息科学与技术学院     1271031   概率论与数理统计B           必      ...        男
# 3    信息科学与技术学院     3006655      电路分析BⅡ           必      ...        男
# 4    信息科学与技术学院     3133000      现代通信原理           必      ...        男
#
#   speciality_code speciality_name student_id teach_class_id teacher  term_id  \
# 0            0403            通信工程   20122169              2     唐慧佳       71
# 1            0403            通信工程   20122169              2     唐慧佳       73
# 2            0403            通信工程   20122169              5     李裕奇       78
# 3            0403            通信工程   20122169              2      郭爱       79
# 4            0403            通信工程   20122169              1      郝莉       73
#
#          term_name term_order constellation
# 0    2014-2015第1学期          1           双子座
# 1  2014-2015第1学期补考          1           双子座
# 2  2015-2016第2学期补考          3           双子座
# 3    2016-2017第1学期          3           双子座
# 4  2014-2015第1学期补考          1           双子座
#
# [5 rows x 28 columns]

# %%
# 按星座性别求平均分和人数
marks.groupby(['constellation','sex'],as_index=False).agg({'pmark':'mean','grade':'count'}).rename(columns={'pmark':'mean','grade':'count'}).to_dict()
# Out:
# {'constellation': {0: '双子座',
#   1: '双子座',
#   2: '双鱼座',
#   3: '双鱼座',
#   4: '处女座',
#   5: '处女座',
#   6: '天秤座',
#   7: '天秤座',
#   8: '天蝎座',
#   9: '天蝎座',
#   10: '射手座',
#   11: '射手座',
#   12: '巨蟹座',
#   13: '巨蟹座',
#   14: '水瓶座',
#   15: '水瓶座',
#   16: '牡羊座',
#   17: '牡羊座',
#   18: '狮子座',
#   19: '狮子座',
#   20: '金牛座',
#   21: '金牛座',
#   22: '魔羯座',
#   23: '魔羯座'},
#  'count': {0: 8,
#   1: 53,
#   2: 22,
#   3: 35,
#   4: 16,
#   5: 59,
#   6: 22,
#   7: 43,
#   8: 20,
#   9: 45,
#   10: 7,
#   11: 39,
#   12: 8,
#   13: 38,
#   14: 13,
#   15: 46,
#   16: 15,
#   17: 33,
#   18: 18,
#   19: 47,
#   20: 12,
#   21: 38,
#   22: 15,
#   23: 41},
#  'mean': {0: 80.83506024293183,
#   1: 77.65087017555014,
#   2: 80.19335151773625,
#   3: 77.69513043681826,
#   4: 83.50588314338069,
#   5: 76.37534502627447,
#   6: 83.68700635702194,
#   7: 76.99323117445243,
#   8: 83.01538086458548,
#   9: 77.98285247501643,
#   10: 80.07246017716851,
#   11: 77.72793223787006,
#   12: 83.1719018966582,
#   13: 74.35539383517879,
#   14: 80.27281307042855,
#   15: 75.58587463634089,
#   16: 78.92020979228958,
#   17: 77.34769197674946,
#   18: 83.2943583596326,
#   19: 76.37537673319889,
#   20: 84.24611690633054,
#   21: 77.70204507076777,
#   22: 80.3728944374632,
#   23: 77.64337577089739},
#  'sex': {0: '女',
#   1: '男',
#   2: '女',
#   3: '男',
#   4: '女',
#   5: '男',
#   6: '女',
#   7: '男',
#   8: '女',
#   9: '男',
#   10: '女',
#   11: '男',
#   12: '女',
#   13: '男',
#   14: '女',
#   15: '男',
#   16: '女',
#   17: '男',
#   18: '女',
#   19: '男',
#   20: '女',
#   21: '男',
#   22: '女',
#   23: '男'}}

# %%
# 按星座求学霸人数
marks[marks['pmark']>90].groupby(['constellation','sex'],as_index=False).agg({'pmark':'count'}).rename(columns={'pmark':'count'})
# Out:
#   constellation sex  count
# 0           双子座   男      1
# 1           处女座   男      1
# 2           天秤座   女      1
# 3           天秤座   男      1
# 4           天蝎座   女      1
# 5           天蝎座   男      1
# 6           牡羊座   男      1
# 7           狮子座   女      1

# %%
# 按星座求学渣人数
marks[marks['pmark']<65].groupby(['constellation','sex'],as_index=False).agg({'pmark':'count'}).rename(columns={'pmark':'count'})
# Out:
#    constellation sex  count
# 0            双子座   男      2
# 1            双鱼座   男      2
# 2            处女座   男      5
# 3            天秤座   男      4
# 4            天蝎座   男      4
# 5            射手座   男      2
# 6            巨蟹座   男      3
# 7            水瓶座   男      4
# 8            牡羊座   男      5
# 9            狮子座   男      4
# 10           金牛座   男      2
# 11           魔羯座   男      2

# %%
# 按星座求挂科人数
df[df['pmark'] < 60].drop_duplicates(subset=['student_id']) \
    .groupby(['constellation','sex'],as_index=False).agg({'pmark':'count'}).rename(columns={'pmark':'count'})
# Out:
#    constellation sex  count
# 0            双子座   女      4
# 1            双子座   男     36
# 2            双鱼座   女     14
# 3            双鱼座   男     19
# 4            处女座   女      7
# 5            处女座   男     42
# 6            天秤座   女      8
# 7            天秤座   男     30
# 8            天蝎座   女      5
# 9            天蝎座   男     27
# 10           射手座   女      3
# 11           射手座   男     28
# 12           巨蟹座   女      2
# 13           巨蟹座   男     24
# 14           水瓶座   女      7
# 15           水瓶座   男     35
# 16           狮子座   女      5
# 17           狮子座   男     31
# 18           白羊座   女      8
# 19           白羊座   男     20
# 20           金牛座   女      3
# 21           金牛座   男     23
# 22           魔羯座   女      8
# 23           魔羯座   男     27

# %% [markdown]
# ## 按民族

# %%
# 按民族性别求平均分和人数
marks.groupby(['nation_name','sex'],as_index=False).agg({'pmark':'mean','grade':'count'}).rename(columns={'pmark':'mean','grade':'count'})
# Out:
#    nation_name sex       mean  count
# 0           侗族   女  70.863154      2
# 1           侗族   男  78.447442      2
# 2           傣族   男  70.746559      1
# 3         哈萨克族   女  68.457500      1
# 4         哈萨克族   男  54.602532      1
# 5           回族   女  77.793312      2
# 6           回族   男  72.765940      3
# 7          土家族   女  82.401426      2
# 8          土家族   男  81.696900      4
# 9           壮族   女  77.215595      2
# 10          壮族   男  79.041898      4
# 11          外籍   男  31.454545      1
# 12         布依族   男  58.330769      1
# 13          彝族   男  79.534568      1
# 14          汉族   女  82.687021    155
# 15          汉族   男  77.186746    485
# 16          满族   女  77.536495      4
# 17          满族   男  75.308955      4
# 18          瑶族   女  79.702500      1
# 19          瑶族   男  74.454667      1
# 20          白族   男  75.363569      2
# 21        维吾尔族   男  69.814457      2
# 22          苗族   女  76.534816      4
# 23          苗族   男  81.897333      1
# 24         蒙古族   女  73.349018      3
# 25         蒙古族   男  74.826169      2
# 26          藏族   男  62.386792      1
# 27          黎族   男  64.553776      1

# %%
# 按民族求学霸人数
marks[marks['pmark']>90].groupby(['nation_name','sex'],as_index=False).agg({'pmark':'count'}).rename(columns={'pmark':'count'})
# Out:
#   nation_name sex  count
# 0          汉族   女      3
# 1          汉族   男      5

# %%
# 按民族求学渣人数
marks[marks['pmark']<65].groupby(['nation_name','sex'],as_index=False).agg({'pmark':'count'}).rename(columns={'pmark':'count'})
# Out:
#   nation_name sex  count
# 0        哈萨克族   男      1
# 1          外籍   男      1
# 2         布依族   男      1
# 3          汉族   男     34
# 4          藏族   男      1
# 5          黎族   男      1

# %%
# 按民族求挂科人数
marks[marks['pmark']<60].groupby(['nation_name','sex'],as_index=False).agg({'pmark':'count'}).rename(columns={'pmark':'count'})
# Out:
#   nation_name sex  count
# 0        哈萨克族   男      1
# 1          外籍   男      1
# 2         布依族   男      1
# 3          汉族   男     22

# %% [markdown]
# ## 按省份

# %%
marks.groupby('province',as_index=False).agg({'pmark':'mean','city':'count'}).rename(columns={'pmark':'mean','city':'count'}).head()
# Out:
#   province       mean  count
# 0       上海  74.507950      4
# 1       云南  72.813413     14
# 2      内蒙古  73.494827      7
# 3       北京  70.552434     10
# 4      北京市  87.236585      1

# %%
# 按省份求学霸人数
marks[marks['pmark']>90].groupby(['province','sex'],as_index=False).agg({'pmark':'count'}).rename(columns={'pmark':'count'})
# Out:
#   province sex  count
# 0       安徽   女      1
# 1       山东   男      2
# 2       广东   男      1
# 3       江苏   女      1
# 4       浙江   女      1
# 5       浙江   男      2

# %%
# 按省份求学渣人数
marks[marks['pmark']<65].groupby(['province','sex'],as_index=False).agg({'pmark':'count'}).rename(columns={'pmark':'count'})
# Out:
#    province sex  count
# 0        云南   男      3
# 1        北京   男      3
# 2        吉林   男      2
# 3        四川   男      8
# 4        安徽   男      1
# 5   安提瓜和巴布达   男      1
# 6        山东   男      1
# 7        山西   男      2
# 8        新疆   男      1
# 9        河北   男      1
# 10       河南   男      1
# 11       湖北   男      1
# 12       湖南   男      3
# 13       西藏   男      1
# 14       贵州   男      4
# 15       辽宁   男      1
# 16       重庆   男      1
# 17       陕西   男      3
# 18      黑龙江   男      1

# %%
# 按省份求挂科人数
marks[marks['pmark']<60].groupby(['province','sex'],as_index=False).agg({'pmark':'count'}).rename(columns={'pmark':'count'})
# Out:
#    province sex  count
# 0        云南   男      3
# 1        北京   男      3
# 2        吉林   男      1
# 3        四川   男      7
# 4   安提瓜和巴布达   男      1
# 5        山西   男      1
# 6        新疆   男      1
# 7        河北   男      1
# 8        湖南   男      1
# 9        贵州   男      3
# 10       辽宁   男      1
# 11       陕西   男      1
# 12      黑龙江   男      1

# %%
sql = "select *,CONVERT(VARCHAR,birthday,112) as birth from view_stu_course_mark " \
                  "where speciality_code='0403' and grade='2014'"
df = jutil.load_pd_df(sql)
len(df)
# Out:
# 13623
